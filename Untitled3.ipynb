# %%
from math import exp, log1p
def rng(m=2**32, a=1103515245, c=12345):
    rng.current = (a * rng.current + c) % m
    return rng.current / m
rng.current = 1

randomExp = [-log1p(-rng())/2 for i in range(1000)] #функция обратная к экспоненциальному распределнию
#по теореме об inverse transform method, F^(-1) от равномерного распределения , есть распределние F
 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


plt.hist(randomExp,density=True)
plt.show()

plt.scatter(randomExp[1:], randomExp[:-1])
plt.show()

# %%
from scipy import stats
import numpy as np
dist = stats.cauchy()
x = np.linspace(-4, 4, 100)
plt.fill_between(x, 0, np.pi*dist.pdf(x)) 
plt.show()

def rng(m=2**32, a=1103515245, c=12345):
    rng.current = (a * rng.current + c) % m
    return rng.current / m
rng.current = 1

random = [rng() for i in range(100)]

#заводим распрделение random, независимо от Коши
#затем проверяем, удовлетворяет ли точка условиям acceptance-rejection метода,
#да - берем, нет - отбрасываем
## соотношение плотностей (функций распределний) должно ограничиваться константой для любой точки
# f(x)/g(x) <= c близкое к 1

mask=np.pi*dist.pdf(random[1:])>random[:-1] 

X=[];Y=[]
for i in range(99):
    if(mask[i]==True):
        X.append(random[i+1])
        Y.append(random[i])

plt.scatter(random[1:], random[:-1],color='black') # rejected points
plt.scatter(X, Y,color='green') #accepted points

x = np.linspace(0, 1, 100)
plt.plot(x,np.pi*dist.pdf(x))
plt.legend(('Cauchy distribution','rejected points', 'accepted points'), loc=(1.04, 0.4))
plt.show()
# Out:
# [0.25693503906950355, 0.5878706516232342, 0.15432575810700655, 0.767266943352297, 0.9738139626570046, 0.5858681506942958, 0.8511155843734741, 0.6132153405342251, 0.7473867232911289, 0.06236015981994569, 0.04194940160959959, 0.1948235605377704, 0.1386128985323012, 0.6840353596489877, 0.49171859584748745, 0.7676989699248224, 0.8828409514389932, 0.8232365751173347, 0.8835694054141641, 0.8901184604037553, 0.9114757110364735, 0.5759661465417594, 0.3127383701503277, 0.15734241367317736, 0.1734505402855575, 0.45860223821364343, 0.2598799681290984, 0.7005771037656814, 0.3033791915513575, 0.8927010844927281, 0.9657614398747683, 0.9349605368915945, 0.9332623495720327, 0.337260173400864, 0.8791998000815511, 0.7909467287827283, 0.1946238619275391, 0.6778173677157611, 0.6001160368323326, 0.41346341953612864, 0.7079516570083797, 0.23176096356473863, 0.4895814983174205, 0.06321822595782578, 0.10631834948435426, 0.4792256865184754, 0.8687314670532942, 0.7045282314065844, 0.8900565332733095, 0.3789496251847595, 0.4784209216013551, 0.5140480131376535, 0.1593637620098889, 0.8784671023022383, 0.6214974857866764, 0.29477110714651644, 0.5217122170142829, 0.9780124833341688, 0.1595665654167533, 0.5296799105126411, 0.22093806276097894, 0.45750992256216705, 0.2861236725002527, 0.5594190212432295, 0.28488548984751105, 0.1260240466799587, 0.7479289369657636, 0.11836701561696827, 0.23848044546321034, 0.2030465758871287, 0.9364988058805466, 0.21348166302777827, 0.6791090513579547, 0.1909938824828714, 0.021589930169284344, 0.08029357832856476, 0.761175709310919, 0.3482904869597405, 0.04855023883283138, 0.7004233116749674, 0.38671589409932494, 0.6224134915973991, 0.671412200666964, 0.11499687586911023, 0.648938633967191, 0.6522729515563697, 0.9436032734811306, 0.5183347112033516, 0.8255736785940826, 0.199303183471784, 0.33814854081720114, 0.8662890878040344, 0.9688983545638621, 0.11664001154713333, 0.9192405361682177, 0.4836049454752356, 0.8893191083334386, 0.7157589511480182, 0.33705125469714403, 0.9046791710425168]

# %%
import matplotlib
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from math import sqrt
n=100
a1=[1,2]
a2=[2,9]
a3=[8,1]
polygon = Polygon(1 * np.array([[1, 2], [2, 9], [8, 1]]), True)
plt.gca().add_collection(PatchCollection([polygon]))

u1,u2=np.random.rand(2, n)
x=[]
y=[]
for i in range(n):
    if u2[i]>u1[i]:
        x.append(u1[i]*a1[0]+(u2[i]-u1[i])*a2[0]+(1-u2[i])*a3[0])
        y.append(u1[i]*a1[1]+(u2[i]-u1[i])*a2[1]+(1-u2[i])*a3[1])
    else:
        x.append(u2[i]*a1[0]+(u1[i]-u2[i])*a2[0]+(1-u1[i])*a3[0])
        y.append(u2[i]*a1[1]+(u1[i]-u2[i])*a2[1]+(1-u1[i])*a3[1])
        #тот квадрат, из которого заполняется треугольник рандомными точками
plt.scatter(x, y,color='m')
plt.show()

# %%
n = 1000
u1, u2 =-1+2*np.random.rand(2, n)
mask=(u1**2+u2**2)>1
while (np.any(mask)==True):
    u11, u22 =-1+2*np.random.rand(2, n)
    u1[mask]=u11[mask]
    u2[mask]=u22[mask]
    mask=(u1**2+u2**2)>1
    
# данный метод основан на использовании метода обратной функции
# проделывая ту же работу что и в алгоритме для экспоненциального распределния получим 
# формулы из задачи выше, теперь так как считать прямое нормальное распределние тяжеловато
# используется распределение Хи-квадрат, сумма квадратов нормального распредления
# из формулы распределения, получим что новое нормальное распределение можно получить из экспоненциального
# приравнивая коэффициент в знаменателе к 0.5, откуда и получается конечная формула (при умножении на sin and cos)
s=u1**2+u2**2
r = np.sqrt(-2 * np.log(s)/s)
x=u1*r
y=u2*r
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].hist2d(x, y, bins=30)
ax[0].axis('equal')
ax[1].hist(x, bins=30)
ax[2].hist(y, bins=30)
ax[0].set_title("2d histogram")
ax[1].set_title("Histogram of x")
ax[2].set_title("Histogram of y")
plt.show()

# %%
#оценим методом монте карло математическое ожидание a
#проведем N независимых испытаний, получим набор x1,..., xn, затем возьмем их среднее - Х
#-по ЗБЧ имеем, что это среднее стремится ,при N->inf, к матожиланию а
#таким образм, можно использовать для больших N, данную величину, однако существует погрешность этого метода
#предположим что случаная величина, задавемая нашим наблюдением имеет конечную дисперсию D
#из утверждения центральной предельной теоремы следует, что для любых у1<y2 справедливо:
#   lim(y1<1/sqrt(ND)*сумма(xi-a)<y2) = "соотвествующий интеграл"
#   когда y1=-y2 = у получится 
#       lim(-y < 1/sqrt(D/N)*сумма(xi-a) < y) = Ф(х) - интеграл вероятностей (табличный)
# тогда Х - а ~ Xb*sqrt(D/N), где Хb из таблицы - коэффициент доверия
#если случайные величины приближены к нормальному, то среднеквадратичное отклонение равно sqrt(D/N)
#
#
#
#
#
#
import matplotlib.pyplot as plt
import numpy as np
import random
def plot_grid(narr):
    colors = np.full_like(narr, 'red', dtype='U5')
    colors[narr==1] = 'black'
    x, y = np.indices((narr.shape))
    plt.scatter(x, y, c=colors.ravel())
    plt.show()

def check(narr,n):
    for i in range(n):
        for j in range(n):
            if narr[i][j]==1:
                if i>0:
                    if narr[i-1][j]==1:
                        narr[i][j]=0
                    elif j>0:
                        if narr[i][j-1]==1:
                            narr[i][j]=0   
                elif j>0:
                    if narr[i][j-1]==1:
                        narr[i][j]=0

def getConfiguration(narr,size,step,plotResult=False):
    for i in range(step):
        x=int(random.randint(0,size-1))
        y=int(random.randint(0,size-1))
        coin=int(random.randint(0,1))
        if coin==1:
            change=True
            if x+1<size:
                if narr[x+1][y]==1:
                    change=False
            if x>0 & change:
                if narr[x-1][y]==1:
                    change=False
            if y+1<size &change:
                if narr[x][y+1]==1:
                    change=False
            if y>0 & change:
                if narr[x][y-1]==1:
                    change=False
            if change==True:
                if narr[x][y]==0:
                    narr[x][y]=1
                
        else:
            if narr[x][y]==1:
                narr[x][y]=0
        
    return np.sum(narr)

from math import exp, gamma
import random
def dinvgamma(alpha, beta,x):
    if x<=0:
        return 0
    print(x)
    return float((beta**alpha)/gamma(alpha)*(x**(-alpha-1))*exp(-beta/x))

def MCMC(n,alpha, beta):
    state = np.random.choice([0], size=(size, size))
    step=10
    sumCom=np.sum(state)
    s=1
    for i in range(n):
        proposal=np.array(state)
        
        y=dinvgamma(alpha,beta,getConfiguration(proposal,size,step))
        x=dinvgamma(alpha,beta,getConfiguration(state,size,step))
        success=0
        if x==0:
            success=1
        else:
            success=y/x
        if 1<=success:
            state=proposal
            sumCom+=np.sum(state)
            s=s+1
    return sumCom/s

def neighbours(narr,x,y,size):
    counter=np.array([0,0])#?
    if(x.size==1):
        return list((counter, 0))
    if x<size-1:
        if narr[x+1][y]==1:
            counter[0]=1
        else:
            counter[1]=1
    if x>0 :
        if narr[x-1][y]==1:
            counter[0]+=1
        else:
            counter[1]+=1
    if y<size-1:
        if narr[x][y+1]==1:
            counter[0]+=1
        else:
            counter[1]+=1
    if y>0:
        if narr[x][y-1]==1:
            counter[0]+=1
        else:
            counter[1]+=1
    return list((counter, (counter[1]-counter[2])))

def getSpinConfiguration(size,beta,plotResult=False):
    top=np.ones(size*size).reshape(size,size)
    bottom=np.array(top)*(-1)
    m=1
    x=np.array([int(random.randint(0,size-1))])
    y=np.array([int(random.randint(0,size-1))])
    uniformRV=np.array([random.random()])
    while True:
        for i in range(2**(m-1)-1):
            expBottom=exp(2*beta*neighbours(bottom,x[i-1],y[i-1],size)[1])
            expTop=exp(2*beta*neighbours(top,x[i-1],y[i-1],size)[1])
            if(uniformRV[i-1]<expBottom/(expBottom+1)):
                bottom[x[i-1]][y[i-1]]=1
            else:
                bottom[x[i-1]][y[i-1]]=-1
            if(uniformRV[i-1]<expTop/(expTop+1)):
                top[x[i-1]][y[i-1]]=1
            else:
                top[x[i-1]][y[i-1]]=-1
        
        if(np.all(bottom==top)==True):
            break
        m=m+1
        x = np.array([int(random.randint(0,size-1)) for i in range(2**(m-1)-1)])
        y = np.array([int(random.randint(0,size-1)) for i in range(2**(m-1)-1)])
        uniformRV=[random.random() for i in range(2**(m-1))]
        top=np.ones(size*size).reshape(size,size)
        bottom=np.array(top)*(-1)

    return list((top,2**m))

size=25
beta=1
narr,step=getSpinConfiguration(size,beta)
narr[narr==-1]=0
check(narr,size)
plot_grid(narr)
n=int(1e4)
E=0
data=np.array([0 for i in range(step)])
for i in range(step):
    data[i]=getConfiguration(narr,size,10)
    E+=data[i]
E/=step
print("step "+str(step))
print("E = "+str(E))
# Out:
# step 16384
# E = 159.4656982421875
